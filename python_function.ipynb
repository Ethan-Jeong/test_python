# %% [markdown]
# <a href="https://colab.research.google.com/github/Ethan-Jeong/test_python/blob/master/python_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.19.5'

# %%
displacement =  307.0
horsepower = 130.0
weight = 3504.0
accel = 12.0
cylinders = 8
origin = 1

# %%
import numpy as np

# %%
def onehotcylinder(cylinders):
  if cylinders == 3:
    cylinder = np.array([1,0,0,0,0])
  elif cylinders == 4:
    cylinder = np.array([0,1,0,0,0])
  elif cylinders == 5:
    cylinder = np.array([0,0,1,0,0])
  elif cylinders == 6:
    cylinder =  np.array([0,0,0,1,0])
  else: #8 
    cylinder =  np.array([0,0,0,0,1]) 
  return cylinder

# %%
onehotcylinder(4)
# Out:
# array([0, 1, 0, 0, 0])

# %%
x_continus  = np.array([ displacement,horsepower,weight, accel ])
onehotcylinder(cylinders)
org = np.array([1,0,0]) # 1

# %%
type(x_continus) , type(cylinder) , type(org) , cylinder
# Out:
# (numpy.ndarray, list, numpy.ndarray, [0, 0, 0, 0, 1])

# %%
# np.concatenate((a, b), axis=None)
result = np.round(np.concatenate((x_continus, cylinder , org ), axis=None))

# %%
result.shape , result
# Out:
# ((12,),
#  array([3.070e+02, 1.300e+02, 3.504e+03, 1.200e+01, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00]))

# %%
# result.reshape(1,12) # result.reshape(-1,result.size)
result = result.reshape(-1,result.size) #

# %%
result
# Out:
# array([[3.070e+02, 1.300e+02, 3.504e+03, 1.200e+01, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00]])

# %%
result.size  , result
# Out:
# (12, array([[3.070e+02, 1.300e+02, 3.504e+03, 1.200e+01, 0.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00]]))

# %% [markdown]
# # Function 이해

# %%
first = 21
second = 14
first + second
# Out:
# 35

# %%
def sum(f01,s02):
  first = s02
  second = f01
  result = first + second  
  return result

# %%
sum(31,22)
# Out:
# 53

# %%
def sum(f1,f2,f3):
  f = f1
  s = f2
  t = f3
  result = f * s * t
  return result

# %%
sum(21,32,2), sum(31,63,41)
# Out:
# (1344, 80073)

# %%
def diffparam(*var_list, **var_dict): # * List , ** Dictionary
  
  print(var_dict)
  result01 = len(var_list)
  
  return result01

# %%
diffparam(1,2,3, a=2,b=3 )
# Out:
# {'a': 2, 'b': 3}
# 3
